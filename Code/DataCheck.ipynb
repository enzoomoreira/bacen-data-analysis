# %%
# ===== Cell 1: Imports e carregamento do arquivo Parquet final corrigido =====
from pathlib import Path # Adicionar import
import pandas as pd

# --- Definir caminhos relativos ---
# Assumindo que DataCheck.ipynb está na pasta 'Code/'
# e a pasta 'Output/' está um nível acima, dentro da raiz do projeto.
notebook_parent_dir = Path('..') # Vai de 'Code/' para 'b3-analise-bancos/'
output_dir = notebook_parent_dir / 'Output'

# Caminhos para os arquivos Parquet
parquet_path = output_dir / 'df_final_corrigido.parquet'
parquet_cosif_full_path = output_dir / 'df_cosif_full_corrigido.parquet' # Renomeei a variável para clareza

# Carrega o DataFrame
df = pd.read_parquet(parquet_path)

# %%
# ===== Cell 2: Checagem básica de dimensões e colunas =====
print("Shape do DataFrame:", df.shape)

print("\nColunas do DataFrame:")
for i, col in enumerate(df.columns, start=1):
    print(f"{i}. {col}")
# Out:
# Shape do DataFrame: (1255244, 19)
#
# Colunas do DataFrame:
# 1. DATA
# 2. DOCUMENTO
# 3. CNPJ
# 4. AGENCIA
# 5. NOME_INSTITUICAO
# 6. TAXONOMIA
# 7. CONTA
# 8. NOME_CONTA
# 9. SALDO
# 10. COD_CONGL
# 11. NOME_CONGL
# 12. TipoInstituicao
# 13. NomeRelatorio
# 14. NumeroRelatorio
# 15. Grupo
# 16. Conta
# 17. NomeColuna
# 18. DescricaoColuna
# 19. Saldo

# %%
# ===== Cell 3: Informações gerais sobre tipos e valores nulos =====
df.info()

print("\nContagem de valores nulos por coluna:")
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1255244 entries, 0 to 1255243
# Data columns (total 19 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   DATA              1255244 non-null  int64
#  1   DOCUMENTO         1255244 non-null  int64
#  2   CNPJ              1255244 non-null  object
#  3   AGENCIA           0 non-null        float64
#  4   NOME_INSTITUICAO  1255244 non-null  object
#  5   TAXONOMIA         1255244 non-null  object
#  6   CONTA             1255244 non-null  int64
#  7   NOME_CONTA        1255244 non-null  object
#  8   SALDO             1255244 non-null  float64
#  9   COD_CONGL         1255244 non-null  object
#  10  NOME_CONGL        1147156 non-null  object
#  11  TipoInstituicao   1078422 non-null  float64
#  12  NomeRelatorio     1078422 non-null  object
#  13  NumeroRelatorio   1078422 non-null  float64
#  14  Grupo             1078422 non-null  object
#  15  Conta             1078422 non-null  float64
#  16  NomeColuna        1078422 non-null  object
#  17  DescricaoColuna   1078422 non-null  object
#  18  Saldo             1074236 non-null  float64
# dtypes: float64(6), int64(3), object(10)
# memory usage: 182.0+ MB
#
# Contagem de valores nulos por coluna:
# DATA                      0
# DOCUMENTO                 0
# CNPJ                      0
# AGENCIA             1255244
# NOME_INSTITUICAO          0
# TAXONOMIA                 0
# CONTA                     0
# NOME_CONTA                0
# SALDO                     0
# COD_CONGL                 0
# NOME_CONGL           108088
# TipoInstituicao      176822
# NomeRelatorio        176822
# NumeroRelatorio      176822
# Grupo                176822
# Conta                176822
# NomeColuna           176822
# DescricaoColuna      176822
# Saldo                181008
# dtype: int64

# %%
# ===== Cell 4: Amostra inicial dos dados =====
display(df.head(10))
# Out:
#      DATA  DOCUMENTO CNPJ  AGENCIA    NOME_INSTITUICAO  \
# 0  202401       4010    0      NaN  BCO DO BRASIL S.A.
# 1  202401       4010    0      NaN  BCO DO BRASIL S.A.
# 2  202401       4010    0      NaN  BCO DO BRASIL S.A.
# 3  202401       4010    0      NaN  BCO DO BRASIL S.A.
# 4  202401       4010    0      NaN  BCO DO BRASIL S.A.
# 5  202401       4010    0      NaN  BCO DO BRASIL S.A.
# 6  202401       4010    0      NaN  BCO DO BRASIL S.A.
# 7  202401       4010    0      NaN  BCO DO BRASIL S.A.
# 8  202401       4010    0      NaN  BCO DO BRASIL S.A.
# 9  202401       4010    0      NaN  BCO DO BRASIL S.A.
#
#                           TAXONOMIA     CONTA  \
# 0  BANCO DO BRASIL - BANCO MULTIPLO  10000007
# 1  BANCO DO BRASIL - BANCO MULTIPLO  11000006
# 2  BANCO DO BRASIL - BANCO MULTIPLO  11100009
# 3  BANCO DO BRASIL - BANCO MULTIPLO  11500001
# 4  BANCO DO BRASIL - BANCO MULTIPLO  12000005
# 5  BANCO DO BRASIL - BANCO MULTIPLO  12100008
# 6  BANCO DO BRASIL - BANCO MULTIPLO  12200001
# 7  BANCO DO BRASIL - BANCO MULTIPLO  12600003
# 8  BANCO DO BRASIL - BANCO MULTIPLO  13000004
# 9  BANCO DO BRASIL - BANCO MULTIPLO  13100007
#
#                                           NOME_CONTA         SALDO COD_CONGL  \
# 0                                   ATIVO REALIZÁVEL  2.122392e+12  C0080329
# 1                                   DISPONIBILIDADES  1.633250e+10  C0080329
# 2                                              Caixa  1.305472e+10  C0080329
# 3            Disponibilidades em Moedas Estrangeiras  3.277780e+09  C0080329
# 4            APLICAÇÕES INTERFINANCEIRAS DE LIQUIDEZ  5.092918e+11  C0080329
# 5             Aplicações em Operações Compromissadas  4.438825e+11  C0080329
# 6           Aplicações em Depósitos Interfinanceiros  9.022786e+09  C0080329
# 7                  Aplicações em Moedas Estrangeiras  5.638651e+10  C0080329
# 8  TÍTULOS E VALORES MOBILIÁRIOS E INSTRUMENTOS F...  4.380087e+11  C0080329
# 9                                             Livres  2.029370e+11  C0080329
#
#         NOME_CONGL  TipoInstituicao NomeRelatorio  NumeroRelatorio Grupo  \
# 0  BB - PRUDENCIAL              NaN          None              NaN  None
# 1  BB - PRUDENCIAL              NaN          None              NaN  None
# 2  BB - PRUDENCIAL              NaN          None              NaN  None
# 3  BB - PRUDENCIAL              NaN          None              NaN  None
# 4  BB - PRUDENCIAL              NaN          None              NaN  None
# 5  BB - PRUDENCIAL              NaN          None              NaN  None
# 6  BB - PRUDENCIAL              NaN          None              NaN  None
# 7  BB - PRUDENCIAL              NaN          None              NaN  None
# 8  BB - PRUDENCIAL              NaN          None              NaN  None
# 9  BB - PRUDENCIAL              NaN          None              NaN  None
#
#    Conta NomeColuna DescricaoColuna  Saldo
# 0    NaN       None            None    NaN
# 1    NaN       None            None    NaN
# 2    NaN       None            None    NaN
# 3    NaN       None            None    NaN
# 4    NaN       None            None    NaN
# 5    NaN       None            None    NaN
# 6    NaN       None            None    NaN
# 7    NaN       None            None    NaN
# 8    NaN       None            None    NaN
# 9    NaN       None            None    NaN

# %%
# ===== Cell 6: Estatísticas descritivas das colunas não numéricas =====
obj_cols = df.select_dtypes(include=['object', 'string']).columns

for col in obj_cols:
    n_unique = df[col].nunique(dropna=False)
    sample_vals = df[col].dropna().unique()[:10]
    print(f"Coluna: {col}")
    print(f"  - Tipo: {df[col].dtype}")
    print(f"  - Valores únicos (até 10 exemplares): {sample_vals.tolist()}")
    print(f"  - Contagem de valores únicos: {n_unique}\n")
# Out:
# Coluna: CNPJ
#   - Tipo: object
#   - Valores únicos (até 10 exemplares): ['0', '208', '360305', '416968', '517645', '556603', '795423', '997185', '1023570', '1181521']
#   - Contagem de valores únicos: 175
#
# Coluna: NOME_INSTITUICAO
#   - Tipo: object
#   - Valores únicos (até 10 exemplares): ['BCO DO BRASIL S.A.', 'BRB - BCO DE BRASILIA S.A.', 'CAIXA ECONOMICA FEDERAL', 'BANCO INTER', 'BCO RIBEIRAO PRETO S.A.', 'BANCO BARI S.A.', 'BANCO SEMEAR', 'BCO B3 S.A.', 'BCO RABOBANK INTL BRASIL S.A.', 'BCO COOPERATIVO SICREDI S.A.']
#   - Contagem de valores únicos: 181
#
# Coluna: TAXONOMIA
#   - Tipo: object
#   - Valores únicos (até 10 exemplares): ['BANCO DO BRASIL - BANCO MULTIPLO', 'BANCOS MULTIPLOS', 'CAIXA ECONOMICA FEDERAL', 'BANCOS COMERCIAIS', 'BANCOS MULTIPLOS COOPERATIVOS', 'BANCOS DE CÂMBIO', 'BANCOS DE INVESTIMENTO', 'BANCOS DE DESENVOLVIMENTO', 'BANCOS COMERCIAIS ESTRAGEIROS - FILIAL PAIS', 'BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO SOCIAL']
#   - Contagem de valores únicos: 10
#
# Coluna: NOME_CONTA
#   - Tipo: object
#   - Valores únicos (até 10 exemplares): ['ATIVO REALIZÁVEL', 'DISPONIBILIDADES', 'Caixa', 'Disponibilidades em Moedas Estrangeiras', 'APLICAÇÕES INTERFINANCEIRAS DE LIQUIDEZ', 'Aplicações em Operações Compromissadas', 'Aplicações em Depósitos Interfinanceiros', 'Aplicações em Moedas Estrangeiras', 'TÍTULOS E VALORES MOBILIÁRIOS E INSTRUMENTOS FINANCEIROS DERIVATIVOS', 'Livres']
#   - Contagem de valores únicos: 172
#
# Coluna: COD_CONGL
#   - Tipo: object
#   - Valores únicos (até 10 exemplares): ['C0080329', 'C0080288', 'C0080738', 'C0080996', 'nan', 'C0080893', 'C0081225', 'C0080745', 'C0080673', 'C0084480']
#   - Contagem de valores únicos: 82
#
# Coluna: NOME_CONGL
#   - Tipo: object
#   - Valores únicos (até 10 exemplares): ['BB - PRUDENCIAL', 'BRB - PRUDENCIAL', 'CAIXA ECONÔMICA FEDERAL - PRUDENCIAL', 'INTER - PRUDENCIAL', 'BANCO BARI DE INVESTIMENTO E FINANCI. - PRUDENCIAL', 'BANCO B3 - PRUDENCIAL', 'BCO COOPERATIVO SICREDI - PRUDENCIAL', 'BNP PARIBAS - PRUDENCIAL', 'BBC S.A. - PRUDENCIAL', 'BANCOOB - PRUDENCIAL']
#   - Contagem de valores únicos: 84
#
# Coluna: NomeRelatorio
#   - Tipo: object
#   - Valores únicos (até 10 exemplares): ['Informações de Capital']
#   - Contagem de valores únicos: 2
#
# Coluna: Grupo
#   - Tipo: object
#   - Valores únicos (até 10 exemplares): ['Patrimônio de Referência para Comparação com o RWA - Patrimônio de Referência Nível I para Comparação com RWA', 'Patrimônio de Referência para Comparação com o RWA', 'Ativos Ponderados pelo Risco (RWA)', 'Ativos Ponderados pelo Risco (RWA) - RWA para Risco de Mercado', 'nan']
#   - Contagem de valores únicos: 6
#
# Coluna: NomeColuna
#   - Tipo: object
#   - Valores únicos (até 10 exemplares): ['Conta_79645', 'Conta_79646', 'Tier_1', 'Tier_2', 'Capital', 'Conta_138232', 'Conta_79652', 'Conta_79653', 'Conta_79654', 'Conta_79655']
#   - Contagem de valores únicos: 24
#
# Coluna: DescricaoColuna
#   - Tipo: object
#   - Valores únicos (até 10 exemplares): ['Parcela do capital de melhor qualidade e imediatamente disponível para absorver perdas', 'Instrumentos de capital e dívida perpétuos, elegíveis como patrimônio regulatório', 'Parcela do capital formada pela soma das parcelas do Capital Principal e Capital Complementar', 'Parcela do capital composta por instrumentos subordinados, elegíveis como patrimônio regulatório, aptos a absorver perdas durante o funcionamento da instituição', 'Montante de capital regulatório formado pela soma das parcelas de Capital Nível I e Capital Nível II', 'RWA para risco de crédito - ajustado', 'Parcela do RWA referente às exposições em ouro, em moeda estrangeira e em ativos sujeitos à variação cambial', 'Parcela do RWA referente ao risco das operações sujeitas à variação do preço de mercadorias (commodities)', 'Parcela do RWA referente às exposições sujeitas à variação de taxas de juros e cupons', 'Parcela do RWA referente ao risco das operações sujeitas à variação do preço de ações']
#   - Contagem de valores únicos: 24

# %%
# ===== Cell 7: Verificação de duplicatas e índice =====
n_duplicated = df.duplicated().sum()
print(f"Total de linhas duplicadas (identicamente iguais): {n_duplicated}")

print("\nÍndice do DataFrame:")
print(df.index)
# Out:
# Total de linhas duplicadas (identicamente iguais): 0
#
# Índice do DataFrame:
# RangeIndex(start=0, stop=1255244, step=1)

# %%
# ===== Cell 8: Amostragem aleatória de linhas =====
display(df.sample(n=5, random_state=42))
# Out:
#            DATA  DOCUMENTO      CNPJ  AGENCIA       NOME_INSTITUICAO  \
# 42231    202403       4010    416968      NaN            BANCO INTER
# 699407   202409       4010  10371492      NaN  BCO YAMAHA MOTOR S.A.
# 7102     202401       4010  28195667      NaN    BCO ABC BRASIL S.A.
# 833981   202409       4010  68900810      NaN    BCO RENDIMENTO S.A.
# 1165103  202412       4016  31597552      NaN      BCO CLASSICO S.A.
#
#                  TAXONOMIA     CONTA  \
# 42231     BANCOS MULTIPLOS  14200009
# 699407    BANCOS MULTIPLOS  31200006
# 7102      BANCOS MULTIPLOS  21200009
# 833981   BANCOS COMERCIAIS  12100008
# 1165103   BANCOS MULTIPLOS  18000009
#
#                                                NOME_CONTA         SALDO  \
# 42231                                 Créditos Vinculados  2.925658e+09
# 699407                         Operações de Risco Nível A  1.783751e+07
# 7102     Participações em Coligadas e Controladas no País  1.143684e+09
# 833981             Aplicações em Operações Compromissadas  7.399866e+08
# 1165103                                   OUTROS CRÉDITOS  2.258366e+08
#
#         COD_CONGL                      NOME_CONGL  TipoInstituicao  \
# 42231    C0080996              INTER - PRUDENCIAL              1.0
# 699407   C0080721       YAMAHA MOTOR - PRUDENCIAL              1.0
# 7102     C0080312         ABC-BRASIL - PRUDENCIAL              NaN
# 833981   C0080659         RENDIMENTO - PRUDENCIAL              1.0
# 1165103  C0081665  BCO CLASSICO S.A. - PRUDENCIAL              1.0
#
#                   NomeRelatorio  NumeroRelatorio  \
# 42231    Informações de Capital              5.0
# 699407   Informações de Capital              5.0
# 7102                       None              NaN
# 833981   Informações de Capital              5.0
# 1165103  Informações de Capital              5.0
#
#                                                      Grupo    Conta  \
# 42231                                                  nan  79661.0
# 699407                  Ativos Ponderados pelo Risco (RWA)  79656.0
# 7102                                                  None      NaN
# 833981   Ativos Ponderados pelo Risco (RWA) - RWA para ...  79655.0
# 1165103  Ativos Ponderados pelo Risco (RWA) - RWA para ...  79652.0
#
#           NomeColuna                                    DescricaoColuna  \
# 42231    Conta_79661  Relação entre o Patrimônio de Referência de Ní...
# 699407          ORWA  Parcela do RWA referente à exposição ao risco ...
# 7102            None                                               None
# 833981   Conta_79655  Parcela do RWA referente ao risco das operaçõe...
# 1165103  Conta_79652  Parcela do RWA referente às exposições em ouro...
#
#                 Saldo
# 42231    1.171410e-01
# 699407   1.575123e+08
# 7102              NaN
# 833981   0.000000e+00
# 1165103  0.000000e+00

# %%
# ===== Cell 9: (Opcional) Carregar df_cosif_full_corrigido para comparações =====
df_cosif_full = pd.read_parquet(parquet_cosif_full_path)

print("Shape de df_cosif_full_corrigido:", df_cosif_full.shape)
print("\nColunas de df_cosif_full_corrigido:")
for i, col in enumerate(df_cosif_full.columns, start=1):
    print(f"{i}. {col}")
# Out:
# Shape de df_cosif_full_corrigido: (224756, 11)
#
# Colunas de df_cosif_full_corrigido:
# 1. DATA
# 2. DOCUMENTO
# 3. CNPJ
# 4. AGENCIA
# 5. NOME_INSTITUICAO
# 6. TAXONOMIA
# 7. CONTA
# 8. NOME_CONTA
# 9. SALDO
# 10. COD_CONGL
# 11. NOME_CONGL

# %%
# ===== Cell 10: (Opcional) Amplitude temporal e quantidade de instituições =====
# Exibe os períodos cobertos e quantos CNPJs distintos existem no final
print("Períodos únicos em df_final_corrigido:", df['DATA'].nunique(), "valores")
print("Instituições únicas em df_final_corrigido:", df['CNPJ'].nunique(), "CNPJs")

# Para o df_cosif_full_corrigido
print("Períodos únicos em df_cosif_full_corrigido:", df_cosif_full['DATA'].nunique())
print("Instituições únicas em df_cosif_full_corrigido:", df_cosif_full['CNPJ'].nunique())
# Out:
# Períodos únicos em df_final_corrigido: 12 valores
# Instituições únicas em df_final_corrigido: 175 CNPJs
# Períodos únicos em df_cosif_full_corrigido: 12
# Instituições únicas em df_cosif_full_corrigido: 175
